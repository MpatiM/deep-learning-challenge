# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
types_count = application_df['APPLICATION_TYPE'].value_counts()
types_count
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(types_count[types_count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_gt1= class_counts.loc[class_counts > 1]
class_counts_gt1
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_dummies = pd.get_dummies(application_df)

# %%
numeric_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                   False
# 1           1    108590              1                   False
# 2           1      5000              0                   False
# 3           1      6692              1                   False
# 4           1    142590              1                   False
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                   False
# 34295       1      5000              0                   False
# 34296       1      5000              0                   False
# 34297       1      5000              1                   False
# 34298       1  36500179              0                   False
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                      True                 False                False
# 1                     False                 False                 True
# 2                     False                 False                False
# 3                     False                 False                 True
# 4                     False                 False                 True
# ...                     ...                   ...                  ...
# 34294                 False                 False                False
# 34295                 False                 False                False
# 34296                 False                 False                 True
# 34297                 False                 False                False
# 34298                 False                 False                 True
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    False                False                False  ...
# 1                    False                False                False  ...
# 2                    False                 True                False  ...
# 3                    False                False                False  ...
# 4                    False                False                False  ...
# ...                    ...                  ...                  ...  ...
# 34294                 True                False                False  ...
# 34295                 True                False                False  ...
# 34296                False                False                False  ...
# 34297                False                 True                False  ...
# 34298                False                False                False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  False                   False                     False
# 1                   True                   False                     False
# 2                  False                   False                     False
# 3                  False                    True                     False
# 4                  False                   False                      True
# ...                  ...                     ...                       ...
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   False             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
# ...                   ...               ...                     ...
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                False              False                      True
# 1                False              False                      True
# 2                False              False                      True
# 3                False              False                      True
# 4                False              False                      True
# ...                ...                ...                       ...
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_dummies['IS_SUCCESSFUL']
X = numeric_dummies.drop(['IS_SUCCESSFUL'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=75)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# OPTIMIZATION - changing activation from tahn to relu for first hidden layer

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(
    units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# OPTIMIZATION - adjusting epochs

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=55)
# Out:
# Epoch 1/55
# 804/804 [==============================] - 7s 5ms/step - loss: 0.9969 - accuracy: 0.6925
# Epoch 2/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.8482 - accuracy: 0.7039
# Epoch 3/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.8956 - accuracy: 0.7095
# Epoch 4/55
# 804/804 [==============================] - 2s 2ms/step - loss: 1.1005 - accuracy: 0.6882
# Epoch 5/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.9261 - accuracy: 0.7065
# Epoch 6/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.8077 - accuracy: 0.7164
# Epoch 7/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7120 - accuracy: 0.7246
# Epoch 8/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.8096 - accuracy: 0.7128
# Epoch 9/55
# 804/804 [==============================] - 3s 3ms/step - loss: 0.7206 - accuracy: 0.6947
# Epoch 10/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6612 - accuracy: 0.7202
# Epoch 11/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6700 - accuracy: 0.7245
# Epoch 12/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6363 - accuracy: 0.7276
# Epoch 13/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6294 - accuracy: 0.7286
# Epoch 14/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6209 - accuracy: 0.7280
# Epoch 15/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6695 - accuracy: 0.7207
# Epoch 16/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6340 - accuracy: 0.7268
# Epoch 17/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6349 - accuracy: 0.7283
# Epoch 18/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.7286
# Epoch 19/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6168 - accuracy: 0.7271
# Epoch 20/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6105 - accuracy: 0.7273
# Epoch 21/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.7287
# Epoch 22/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6073 - accuracy: 0.7313
# Epoch 23/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6060 - accuracy: 0.7295
# Epoch 24/55
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6009 - accuracy: 0.7315
# Epoch 25/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5985 - accuracy: 0.7317
# Epoch 26/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5983 - accuracy: 0.7308
# Epoch 27/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6009 - accuracy: 0.7292
# Epoch 28/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6069 - accuracy: 0.7262
# Epoch 29/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6018 - accuracy: 0.7284
# Epoch 30/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6035 - accuracy: 0.7297
# Epoch 31/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6051 - accuracy: 0.7301
# Epoch 32/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5975 - accuracy: 0.7317
# Epoch 33/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5964 - accuracy: 0.7316
# Epoch 34/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5921 - accuracy: 0.7311
# Epoch 35/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7309
# Epoch 36/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7307
# Epoch 37/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5821 - accuracy: 0.7326
# Epoch 38/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5970 - accuracy: 0.7310
# Epoch 39/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5819 - accuracy: 0.7319
# Epoch 40/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5834 - accuracy: 0.7304
# Epoch 41/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5831 - accuracy: 0.7324
# Epoch 42/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5820 - accuracy: 0.7294
# Epoch 43/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5839 - accuracy: 0.7296
# Epoch 44/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5823 - accuracy: 0.7324
# Epoch 45/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5835 - accuracy: 0.7305
# Epoch 46/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5823 - accuracy: 0.7315
# Epoch 47/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5851 - accuracy: 0.7330
# Epoch 48/55
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5887 - accuracy: 0.7336
# Epoch 49/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5896 - accuracy: 0.7246
# Epoch 50/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5811 - accuracy: 0.7342
# Epoch 51/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7333
# Epoch 52/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5802 - accuracy: 0.7328
# Epoch 53/55
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5834 - accuracy: 0.7331
# Epoch 54/55
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5898 - accuracy: 0.7334
# Epoch 55/55
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5791 - accuracy: 0.7337

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5978 - accuracy: 0.7355 - 492ms/epoch - 2ms/step
# Loss: 0.597781240940094, Accuracy: 0.7355102300643921

# %%
# Export our model to HDF5 file
nn_model.save("./AlphabetSoupCharity_2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = tf.keras.models.load_model('AlphabetSoupCharity_2.h5')

# Show the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
